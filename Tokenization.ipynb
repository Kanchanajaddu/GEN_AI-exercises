# %% [markdown]
# <a href="https://colab.research.google.com/github/Kanchanajaddu/GEN_AI-exercises/blob/main/Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tokenization

# %%
#tokens
from transformers import BertTokenizer
tokenizer=BertTokenizer.from_pretrained("bert-base-cased")
tokens=tokenizer.tokenize("this is for tokenization")
print(tokens)
# Out:
# ['this', 'is', 'for', 'token', '##ization']

# %%
#convet into ids
ids=tokenizer.convert_tokens_to_ids(tokens)
print(ids)
# Out:
# [1142, 1110, 1111, 22559, 2734]

# %%
#decoding
decoded_string=tokenizer.decode(ids)
print(decoded_string)
# Out:
# this is for tokenization

# %%
#saving
tokenizer.save_pretrained("my_tokenizer")
# Out:
# ('my_tokenizer/tokenizer_config.json', 'my_tokenizer/tokenizer.json')
